# %%
import pandas as pd
def check_employee():
    i = input("Enter your  first name:")
    #j = input("Enter your surname:")
    #k = input("Enter your department:")
    data = pd.read_csv("jt-ventures.csv")
    df = pd.DataFrame(data)
    columns = list(df)
    
    for i in columns:
        if i == (df['i[0]']):
            and j ==(df["FIRST NAME"])
            and k ==(df["DEPARTMENT"])
        
#check_employee()

# %%
#PROJECT 2
def price():
    location = input("Enter your location:")
    weight = int(input("Enter your package weight:"))

    if location == "Ibeju-Lekki" and (weight >= 10):
        print("price = N2000")
    elif location =="Ibeju-Lekki" and (weight < 10):
        print("price = N1500")
    elif location == "Epe" and weight >= 10:
        print("price = N5000")
    elif location == "Epe" and (weight < 10):
        print("price = N4000")
    else: print("No information available")

price()

# %%
#Project 3
import pandas as pd

name = input("Enter your name:")
department = input("Computer Science - A\n Mass Communication - B\nEnter a course")

def comp_sci():
    jamb_score = int(input("Enter your jamb score:"))
    credits = int(input("Enter the number of subjects with C and above:"))
    interview = input("Did you pass the interview? (Enter y if yes, enter n if no)")

    if jamb_score >= 230 and credits >= 5 and interview == "y":
        print("You have been admitted into the Computer Science department")
        records = {'name': [name],'Jamb_score':[jamb_score],'No_of_credits':[credits],
            'interview':[interview] }

        df = pd.DataFrame(records)
        df.to_csv('admitted.csv')
    else: 
            records = {'name': [name],'Jamb_score':[jamb_score],'No_of_credits':[credits],
            'interview':[interview] }

            df = pd.DataFrame(records)
            df.to_csv('not-admitted.csv')

def mass_com():
    jamb_score = int(input("Enter your jamb score:"))
    credits = int(input("Enter the number of subjects with C and above:"))
    interview = input("Did you pass the interview? (Enter y if yes, enter n if no)")

        if jamb_score >= 220 and credits >= 5 and interview == "y":
            print("You have been admitted into the Computer Science department")
                records = {'name': [name],'Jamb_score':[jamb_score],'No_of_credits':[credits],
                    'interview':[interview] }

        df = pd.DataFrame(records)
        df.to_csv('admitted.csv')
        else: 
                records = {'NAME': [name],'JAMB-SCORE':[jamb_score],'NO_OF_CREDITS':[credits],
                'PASSED_INTERVIEW':[interview] }

                df = pd.DataFrame(records)
                df.to_csv('not-admitted.csv')



if department == "A":
            comp_sci()
if department == "B":
            mass_com()
